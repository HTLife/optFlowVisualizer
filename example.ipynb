# %%
# %matplotlib inline
import flowlib

flow = flowlib.read_flo_file('./flow.flo')
#flowlib.save_flow_png(flow)
flowlib.mp_show(flow)
# Out:
# max flow: 164.3969
# flow range:
# u = -93.781 .. 163.296
# v = -45.278 .. 78.279
